# %%
import os
import numpy as np
import librosa
import soundfile as sf

def rms_level(audio):
    return np.sqrt(np.mean(audio**2))

def match_rms(source_audio, target_audio):
    source_rms = rms_level(source_audio)
    
    target_rms = rms_level(target_audio)
    
    print(source_rms, target_rms)
    scalar = (target_rms + 1e-10) / (source_rms + 1e-10)
    return source_audio * scalar

def normalize_folder(folder1, folder2, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for file_name in os.listdir(folder1):
        if file_name.endswith(".wav"):
            path1 = os.path.join(folder1, file_name)
            path2 = os.path.join(folder2, file_name)

            if not os.path.exists(path2):
                print(f"Skip: {file_name}")
                continue

            # Carica entrambi
            audio1, sr1 = librosa.load(path1, sr=None)
            audio2, sr2 = librosa.load(path2, sr=None)

            if sr1 != sr2:
                print(f"Skip {file_name}, different sample rate.")
                continue

            # Normalizza audio1 come audio2
            normalized = match_rms(audio1, audio2)

            # Salva
            output_path = os.path.join(output_folder, file_name)
            sf.write(output_path, normalized, sr1)
            print(f"Normalized: {file_name}")


normalize_folder("/home/ms_ablasioli/alessandra/denoiser_backup_bcn/vibravox/noise_air_test_bcn", "/home/ms_ablasioli/alessandra/denoiser_backup_bcn/vibravox/noise_bone_test_bcn", "/home/ms_ablasioli/alessandra/denoiser_backup_bcn/norm1/noise_air_test_bcn_norm1")
# Out:
# Normalizzato: output973.wav
# Normalizzato: output972.wav
# Normalizzato: output974.wav
# Normalizzato: output975.wav
# Normalizzato: output976.wav
# Normalizzato: output977.wav
# Normalizzato: output978.wav
# Normalizzato: output979.wav
# Normalizzato: output98.wav
# Normalizzato: output980.wav
# Normalizzato: output981.wav
# Normalizzato: output982.wav
# Normalizzato: output983.wav
# Normalizzato: output984.wav
# Normalizzato: output985.wav
# Normalizzato: output986.wav
# Normalizzato: output987.wav
# Normalizzato: output988.wav
# Normalizzato: output989.wav
# Normalizzato: output99.wav
# Normalizzato: output990.wav
# Normalizzato: output991.wav
# Normalizzato: output992.wav
# Normalizzato: output993.wav
# Normalizzato: output994.wav
# Normalizzato: output995.wav
# Normalizzato: output996.wav
# Normalizzato: output997.wav
# Normalizzato: output998.wav
# Normalizzato: output999.wav
# Normalizzato: output2409.wav
# Normalizzato: output241.wav
# Normalizzato: output2410.wav
# Normalizzato: output2411.wav
# Normalizzato: output2412.wav
# Normalizzato: output2413.wav
# Normalizzato: output2414.wav
# Normalizzato: output2415.wav
# Normalizzato: output2416.wav
# Normalizzato: output2417.wav
# Normalizzato: output2418.wav
# Normalizzato: output2419.wav
# Normalizzato: output242.wav
# Normalizzato: output2420.wav
# Normalizzato: output2421.wav
# Normalizzato: output2422.wav
# Normalizzato: output2423.wav
# Normalizzato: output2424.wav
# Normalizzato: output2425.wav
# Normalizzato: output2426.wav
# Normalizzato: output2427.wav
# Normalizzato: output2428.wav
# Normalizzato: output2429.wav
# Normalizzato: output1819.wav
# Normalizzato: output182.wav
# Normalizzato: output1820.wav
# Normalizzato: output1821.wav
# Normalizzato: output1822.wav
# Normalizzato: output1823.wav
# Normalizzato: output1824.wav
# Normalizzato: output1825.wav
# Normalizzato: output1826.wav
# Normalizzato: output1827.wav
# Normalizzato: output1828.wav
# Normalizzato: output1829.wav
# Normalizzato: output183.wav
# Normalizzato: output1830.wav
# Normalizzato: output1831.wav
# Normalizzato: output1832.wav
# Normalizzato: output1833.wav
# Normalizzato: output1834.wav
# Normalizzato: output1835.wav
# Normalizzato: output1836.wav
# Normalizzato: output2991.wav
# Normalizzato: output2992.wav
# Normalizzato: output2993.wav
# Normalizzato: output2994.wav
# Normalizzato: output2995.wav
# Normalizzato: output2996.wav
# Normalizzato: output2997.wav
# Normalizzato: output2998.wav
# Normalizzato: output2999.wav
# Normalizzato: output3.wav
# Normalizzato: output30.wav
# Normalizzato: output300.wav
# Normalizzato: output3000.wav
# Normalizzato: output3001.wav
# Normalizzato: output3002.wav
# Normalizzato: output3003.wav
# Normalizzato: output3004.wav
# Normalizzato: output3005.wav
# Normalizzato: output3006.wav
# Normalizzato: output3007.wav
# Normalizzato: output3008.wav
# Normalizzato: output3009.wav
# Normalizzato: output301.wav
# Normalizzato: output3010.wav
# Normalizzato: output3011.wav
# Normalizzato: output3012.wav
# Normalizzato: output3013.wav
# Normalizzato: output3014.wav
# Normalizzato: output1458.wav
# Normalizzato: output1459.wav
# Normalizzato: output146.wav
# Normalizzato: output1460.wav
# Normalizzato: output1461.wav
# Normalizzato: output1462.wav
# Normalizzato: output1463.wav
# Normalizzato: output1464.wav
# Normalizzato: output1465.wav
# Normalizzato: output1466.wav
# Normalizzato: output1467.wav
# Normalizzato: output1468.wav
# Normalizzato: output1469.wav
# Normalizzato: output147.wav
# Normalizzato: output1470.wav
# Normalizzato: output1471.wav
# Normalizzato: output1472.wav
# Normalizzato: output1473.wav
# Normalizzato: output41.wav
# Normalizzato: output434.wav
# Normalizzato: output453.wav
# Normalizzato: output474.wav
# Normalizzato: output491.wav
# Normalizzato: output51.wav
# Normalizzato: output533.wav
# Normalizzato: output561.wav
# Normalizzato: output588.wav
# Normalizzato: output61.wav
# Normalizzato: output631.wav
# Normalizzato: output652.wav
# Normalizzato: output683.wav
# Normalizzato: output702.wav
# Normalizzato: output72.wav
# Normalizzato: output741.wav
# Normalizzato: output77.wav
# Normalizzato: output787.wav
# Normalizzato: output803.wav
# Normalizzato: output82.wav
# Normalizzato: output837.wav
# Normalizzato: output855.wav
# Normalizzato: output871.wav
# Normalizzato: output889.wav
# Normalizzato: output906.wav
# Normalizzato: output927.wav
# Normalizzato: output946.wav
# Normalizzato: output971.wav
# Normalizzato: output632.wav
# Normalizzato: output633.wav
# Normalizzato: output634.wav
# Normalizzato: output635.wav
# Normalizzato: output636.wav
# Normalizzato: output637.wav
# Normalizzato: output638.wav
# Normalizzato: output639.wav
# Normalizzato: output64.wav
# Normalizzato: output640.wav
# Normalizzato: output641.wav
# Normalizzato: output642.wav
# Normalizzato: output643.wav
# Normalizzato: output644.wav
# Normalizzato: output645.wav
# Normalizzato: output646.wav
# Normalizzato: output647.wav
# Normalizzato: output648.wav
# Normalizzato: output649.wav
# Normalizzato: output65.wav
# Normalizzato: output650.wav
# Normalizzato: output651.wav
# Normalizzato: output219.wav
# Normalizzato: output2190.wav
# Normalizzato: output2191.wav
# Normalizzato: output2192.wav
# Normalizzato: output2193.wav
# Normalizzato: output2194.wav
# Normalizzato: output2195.wav
# Normalizzato: output2196.wav
# Normalizzato: output2197.wav
# Normalizzato: output2198.wav
# Normalizzato: output2199.wav
# Normalizzato: output22.wav
# Normalizzato: output220.wav
# Normalizzato: output2200.wav
# Normalizzato: output2201.wav
# Normalizzato: output2202.wav
# Normalizzato: output2203.wav
# Normalizzato: output2204.wav
# Normalizzato: output2205.wav
# Normalizzato: output2206.wav
# Normalizzato: output2207.wav
# Normalizzato: output2208.wav
# Normalizzato: output2209.wav
# Normalizzato: output221.wav
# Normalizzato: output2210.wav
# Normalizzato: output2211.wav
# Normalizzato: output2212.wav
# Normalizzato: output2213.wav
# Normalizzato: output2214.wav
# Normalizzato: output2215.wav
# Normalizzato: output2639.wav
# Normalizzato: output264.wav
# Normalizzato: output2640.wav
# Normalizzato: output2641.wav
# Normalizzato: output2642.wav
# Normalizzato: output2643.wav
# Normalizzato: output2644.wav
# Normalizzato: output2645.wav
# Normalizzato: output2646.wav
# Normalizzato: output2647.wav
# Normalizzato: output2648.wav
# Normalizzato: output2649.wav
# Normalizzato: output265.wav
# Normalizzato: output2650.wav
# Normalizzato: output2651.wav
# Normalizzato: output2652.wav
# Normalizzato: output2653.wav
# Normalizzato: output2654.wav
# Normalizzato: output2655.wav
# Normalizzato: output2656.wav
# Normalizzato: output2657.wav
# Normalizzato: output2658.wav
# Normalizzato: output2659.wav
# Normalizzato: output266.wav
# Normalizzato: output2660.wav
# Normalizzato: output2661.wav
# Normalizzato: output2662.wav
# Normalizzato: output2663.wav
# Normalizzato: output2664.wav
# Normalizzato: output2665.wav
# Normalizzato: output2666.wav
# Normalizzato: output492.wav
# Normalizzato: output493.wav
# Normalizzato: output494.wav
# Normalizzato: output495.wav
# Normalizzato: output496.wav
# Normalizzato: output497.wav
# Normalizzato: output498.wav
# Normalizzato: output499.wav
# Normalizzato: output5.wav
# Normalizzato: output50.wav
# Normalizzato: output500.wav
# Normalizzato: output501.wav
# Normalizzato: output502.wav
# Normalizzato: output503.wav
# Normalizzato: output504.wav
# Normalizzato: output505.wav
# Normalizzato: output506.wav
# Normalizzato: output507.wav
# Normalizzato: output508.wav
# Normalizzato: output509.wav
# Normalizzato: output1162.wav
# Normalizzato: output1163.wav
# Normalizzato: output1164.wav
# Normalizzato: output1165.wav
# Normalizzato: output1166.wav
# Normalizzato: output1167.wav
# Normalizzato: output1168.wav
# Normalizzato: output1169.wav
# Normalizzato: output117.wav
# Normalizzato: output1170.wav
# Normalizzato: output1171.wav
# Normalizzato: output1172.wav
# Normalizzato: output1173.wav
# Normalizzato: output1174.wav
# Normalizzato: output1175.wav
# Normalizzato: output1176.wav
# Normalizzato: output1177.wav
# Normalizzato: output1178.wav
# Normalizzato: output1179.wav
# Normalizzato: output118.wav
# Normalizzato: output1180.wav
# Normalizzato: output1181.wav
# Normalizzato: output1182.wav
# Normalizzato: output1183.wav
# Normalizzato: output1184.wav
# Normalizzato: output1185.wav
# Normalizzato: output1186.wav
# Normalizzato: output1187.wav
# Normalizzato: output1188.wav
# Normalizzato: output1633.wav
# Normalizzato: output1634.wav
# Normalizzato: output1635.wav
# Normalizzato: output1636.wav
# Normalizzato: output1637.wav
# Normalizzato: output1638.wav
# Normalizzato: output1639.wav
# Normalizzato: output164.wav
# Normalizzato: output1640.wav
# Normalizzato: output1641.wav
# Normalizzato: output1642.wav
# Normalizzato: output1643.wav
# Normalizzato: output1644.wav
# Normalizzato: output1645.wav
# Normalizzato: output1646.wav
# Normalizzato: output1647.wav
# Normalizzato: output1648.wav
# Normalizzato: output1649.wav
# Normalizzato: output165.wav
# Normalizzato: output1650.wav
# Normalizzato: output1651.wav
# Normalizzato: output1652.wav
# Normalizzato: output1653.wav
# Normalizzato: output1654.wav
# Normalizzato: output1655.wav
# Normalizzato: output1656.wav
# Normalizzato: output1657.wav
# Normalizzato: output1658.wav
# Normalizzato: output1659.wav
# Normalizzato: output742.wav
# Normalizzato: output743.wav
# Normalizzato: output744.wav
# Normalizzato: output745.wav
# Normalizzato: output746.wav
# Normalizzato: output747.wav
# Normalizzato: output748.wav
# Normalizzato: output749.wav
# Normalizzato: output75.wav
# Normalizzato: output750.wav
# Normalizzato: output751.wav
# Normalizzato: output752.wav
# Normalizzato: output753.wav
# Normalizzato: output754.wav
# Normalizzato: output755.wav
# Normalizzato: output756.wav
# Normalizzato: output757.wav
# Normalizzato: output758.wav
# Normalizzato: output759.wav
# Normalizzato: output76.wav
# Normalizzato: output760.wav
# Normalizzato: output761.wav
# Normalizzato: output762.wav
# Normalizzato: output763.wav
# Normalizzato: output764.wav
# Normalizzato: output765.wav
# Normalizzato: output766.wav
# Normalizzato: output767.wav
# Normalizzato: output768.wav
# Normalizzato: output769.wav
# Normalizzato: output1984.wav
# Normalizzato: output1985.wav
# Normalizzato: output1986.wav
# Normalizzato: output1987.wav
# Normalizzato: output1988.wav
# Normalizzato: output1989.wav
# Normalizzato: output199.wav
# Normalizzato: output1990.wav
# Normalizzato: output1991.wav
# Normalizzato: output1992.wav
# Normalizzato: output1993.wav
# Normalizzato: output1994.wav
# Normalizzato: output1995.wav
# Normalizzato: output1996.wav
# Normalizzato: output1997.wav
# Normalizzato: output1998.wav
# Normalizzato: output1999.wav
# Normalizzato: output2.wav
# Normalizzato: output20.wav
# Normalizzato: output200.wav
# Normalizzato: output2000.wav
# Normalizzato: output2839.wav
# Normalizzato: output284.wav
# Normalizzato: output2840.wav
# Normalizzato: output2841.wav
# Normalizzato: output2842.wav
# Normalizzato: output2843.wav
# Normalizzato: output2844.wav
# Normalizzato: output2845.wav
# Normalizzato: output2846.wav
# Normalizzato: output2847.wav
# Normalizzato: output2848.wav
# Normalizzato: output2849.wav
# Normalizzato: output285.wav
# Normalizzato: output2850.wav
# Normalizzato: output2851.wav
# Normalizzato: output2852.wav
# Normalizzato: output2853.wav
# Normalizzato: output2854.wav
# Normalizzato: output2855.wav
# Normalizzato: output2304.wav
# Normalizzato: output2305.wav
# Normalizzato: output2306.wav
# Normalizzato: output2307.wav
# Normalizzato: output2308.wav
# Normalizzato: output2309.wav
# Normalizzato: output231.wav
# Normalizzato: output2310.wav
# Normalizzato: output2311.wav
# Normalizzato: output2312.wav
# Normalizzato: output2313.wav
# Normalizzato: output2314.wav
# Normalizzato: output2315.wav
# Normalizzato: output2316.wav
# Normalizzato: output2317.wav
# Normalizzato: output2318.wav
# Normalizzato: output2319.wav
# Normalizzato: output232.wav
# Normalizzato: output2320.wav
# Normalizzato: output2321.wav
# Normalizzato: output2322.wav
# Normalizzato: output2323.wav
# Normalizzato: output2324.wav
# Normalizzato: output2325.wav
# Normalizzato: output2326.wav
# Normalizzato: output2327.wav
# Normalizzato: output2328.wav
# Normalizzato: output2329.wav
# Normalizzato: output1281.wav
# Normalizzato: output1282.wav
# Normalizzato: output1283.wav
# Normalizzato: output1284.wav
# Normalizzato: output1285.wav
# Normalizzato: output1286.wav
# Normalizzato: output1287.wav
# Normalizzato: output1288.wav
# Normalizzato: output1289.wav
# Normalizzato: output129.wav
# Normalizzato: output1290.wav
# Normalizzato: output1291.wav
# Normalizzato: output1292.wav
# Normalizzato: output1293.wav
# Normalizzato: output13.wav
# Normalizzato: output1295.wav
# Normalizzato: output1294.wav
# Normalizzato: output1296.wav
# Normalizzato: output1297.wav
# Normalizzato: output1298.wav
# Normalizzato: output1299.wav
# Normalizzato: output130.wav
# Normalizzato: output1300.wav
# Normalizzato: output1301.wav
# Normalizzato: output89.wav
# Normalizzato: output890.wav
# Normalizzato: output891.wav
# Normalizzato: output892.wav
# Normalizzato: output893.wav
# Normalizzato: output894.wav
# Normalizzato: output895.wav
# Normalizzato: output896.wav
# Normalizzato: output897.wav
# Normalizzato: output898.wav
# Normalizzato: output899.wav
# Normalizzato: output9.wav
# Normalizzato: output90.wav
# Normalizzato: output900.wav
# Normalizzato: output901.wav
# Normalizzato: output902.wav
# Normalizzato: output903.wav
# Normalizzato: output904.wav
# Normalizzato: output905.wav
# Normalizzato: output2096.wav
# Normalizzato: output2097.wav
# Normalizzato: output2098.wav
# Normalizzato: output2099.wav
# Normalizzato: output21.wav
# Normalizzato: output210.wav
# Normalizzato: output2100.wav
# Normalizzato: output2101.wav
# Normalizzato: output2102.wav
# Normalizzato: output2103.wav
# Normalizzato: output2104.wav
# Normalizzato: output2105.wav
# Normalizzato: output2106.wav
# Normalizzato: output2107.wav
# Normalizzato: output2108.wav
# Normalizzato: output2109.wav
# Normalizzato: output211.wav
# Normalizzato: output2110.wav
# Normalizzato: output2111.wav
# Normalizzato: output2112.wav
# Normalizzato: output2113.wav
# Normalizzato: output2114.wav
# Normalizzato: output2115.wav
# Normalizzato: output2116.wav
# Normalizzato: output172.wav
# Normalizzato: output1720.wav
# Normalizzato: output1721.wav
# Normalizzato: output1722.wav
# Normalizzato: output1723.wav
# Normalizzato: output1724.wav
# Normalizzato: output1725.wav
# Normalizzato: output1726.wav
# Normalizzato: output1727.wav
# Normalizzato: output1728.wav
# Normalizzato: output1729.wav
# Normalizzato: output173.wav
# Normalizzato: output1730.wav
# Normalizzato: output1731.wav
# Normalizzato: output1732.wav
# Normalizzato: output1733.wav
# Normalizzato: output1734.wav
# Normalizzato: output1735.wav
# Normalizzato: output1736.wav
# Normalizzato: output1737.wav
# Normalizzato: output1738.wav
# Normalizzato: output1739.wav
# Normalizzato: output174.wav
# Normalizzato: output1740.wav
# Normalizzato: output1741.wav
# Normalizzato: output1742.wav
# Normalizzato: output1743.wav
# Normalizzato: output410.wav
# Normalizzato: output411.wav
# Normalizzato: output412.wav
# Normalizzato: output413.wav
# Normalizzato: output414.wav
# Normalizzato: output415.wav
# Normalizzato: output416.wav
# Normalizzato: output417.wav
# Normalizzato: output418.wav
# Normalizzato: output419.wav
# Normalizzato: output42.wav
# Normalizzato: output420.wav
# Normalizzato: output421.wav
# Normalizzato: output422.wav
# Normalizzato: output423.wav
# Normalizzato: output424.wav
# Normalizzato: output425.wav
# Normalizzato: output426.wav
# Normalizzato: output427.wav
# Normalizzato: output428.wav
# Normalizzato: output429.wav
# Normalizzato: output43.wav
# Normalizzato: output430.wav
# Normalizzato: output431.wav
# Normalizzato: output432.wav
# Normalizzato: output433.wav
# Normalizzato: output2515.wav
# Normalizzato: output2516.wav
# Normalizzato: output2517.wav
# Normalizzato: output2518.wav
# Normalizzato: output2519.wav
# Normalizzato: output252.wav
# Normalizzato: output2520.wav
# Normalizzato: output2521.wav
# Normalizzato: output2522.wav
# Normalizzato: output2523.wav
# Normalizzato: output2524.wav
# Normalizzato: output2525.wav
# Normalizzato: output2526.wav
# Normalizzato: output2527.wav
# Normalizzato: output2528.wav
# Normalizzato: output2529.wav
# Normalizzato: output253.wav
# Normalizzato: output2530.wav
# Normalizzato: output2531.wav
# Normalizzato: output2532.wav
# Normalizzato: output2533.wav
# Normalizzato: output2534.wav
# Normalizzato: output2535.wav
# Normalizzato: output2536.wav
# Normalizzato: output2537.wav
# Normalizzato: output2538.wav
# Normalizzato: output1538.wav
# Normalizzato: output1539.wav
# Normalizzato: output154.wav
# Normalizzato: output1540.wav
# Normalizzato: output1541.wav
# Normalizzato: output1542.wav
# Normalizzato: output1543.wav
# Normalizzato: output1544.wav
# Normalizzato: output1545.wav
# Normalizzato: output1546.wav
# Normalizzato: output1547.wav
# Normalizzato: output1548.wav
# Normalizzato: output1549.wav
# Normalizzato: output155.wav
# Normalizzato: output1550.wav
# Normalizzato: output1551.wav
# Normalizzato: output1552.wav
# Normalizzato: output1553.wav
# Normalizzato: output1554.wav
# Normalizzato: output1555.wav
# Normalizzato: output1556.wav
# Normalizzato: output1557.wav
# Normalizzato: output2898.wav
# Normalizzato: output2899.wav
# Normalizzato: output29.wav
# Normalizzato: output290.wav
# Normalizzato: output2900.wav
# Normalizzato: output2901.wav
# Normalizzato: output2902.wav
# Normalizzato: output2903.wav
# Normalizzato: output2904.wav
# Normalizzato: output2905.wav
# Normalizzato: output2906.wav
# Normalizzato: output2907.wav
# Normalizzato: output2908.wav
# Normalizzato: output2909.wav
# Normalizzato: output291.wav
# Normalizzato: output2910.wav
# Normalizzato: output2911.wav
# Normalizzato: output2912.wav
# Normalizzato: output2913.wav
# Normalizzato: output2914.wav
# Normalizzato: output2915.wav
# Normalizzato: output2916.wav
# Normalizzato: output2917.wav
# Normalizzato: output2918.wav
# Normalizzato: output2919.wav
# Normalizzato: output292.wav
# Normalizzato: output2920.wav
# Normalizzato: output2921.wav
# Normalizzato: output2922.wav
# Normalizzato: output2923.wav
# Normalizzato: output2924.wav
# Normalizzato: output2732.wav
# Normalizzato: output2733.wav
# Normalizzato: output2734.wav
# Normalizzato: output2735.wav
# Normalizzato: output2736.wav
# Normalizzato: output2737.wav
# Normalizzato: output2738.wav
# Normalizzato: output2739.wav
# Normalizzato: output274.wav
# Normalizzato: output2740.wav
# Normalizzato: output2741.wav
# Normalizzato: output2742.wav
# Normalizzato: output2743.wav
# Normalizzato: output2744.wav
# Normalizzato: output2745.wav
# Normalizzato: output2746.wav
# Normalizzato: output2747.wav
# Normalizzato: output2748.wav
# Normalizzato: output2749.wav
# Normalizzato: output275.wav
# Normalizzato: output534.wav
# Normalizzato: output535.wav
# Normalizzato: output536.wav
# Normalizzato: output537.wav
# Normalizzato: output538.wav
# Normalizzato: output539.wav
# Normalizzato: output54.wav
# Normalizzato: output540.wav
# Normalizzato: output541.wav
# Normalizzato: output542.wav
# Normalizzato: output543.wav
# Normalizzato: output544.wav
# Normalizzato: output545.wav
# Normalizzato: output546.wav
# Normalizzato: output547.wav
# Normalizzato: output548.wav
# Normalizzato: output549.wav
# Normalizzato: output55.wav
# Normalizzato: output550.wav
# Normalizzato: output551.wav
# Normalizzato: output552.wav
# Normalizzato: output553.wav
# Normalizzato: output554.wav
# Normalizzato: output555.wav
# Normalizzato: output556.wav
# Normalizzato: output557.wav
# Normalizzato: output558.wav
# Normalizzato: output559.wav
# Normalizzato: output56.wav
# Normalizzato: output560.wav
# Normalizzato: output1908.wav
# Normalizzato: output1909.wav
# Normalizzato: output191.wav
# Normalizzato: output1910.wav
# Normalizzato: output1911.wav
# Normalizzato: output1912.wav
# Normalizzato: output1913.wav
# Normalizzato: output1914.wav
# Normalizzato: output1915.wav
# Normalizzato: output1916.wav
# Normalizzato: output1917.wav
# Normalizzato: output1918.wav
# Normalizzato: output1919.wav
# Normalizzato: output192.wav
# Normalizzato: output1920.wav
# Normalizzato: output1921.wav
# Normalizzato: output1922.wav
# Normalizzato: output1923.wav
# Normalizzato: output1379.wav
# Normalizzato: output138.wav
# Normalizzato: output1380.wav
# Normalizzato: output1381.wav
# Normalizzato: output1382.wav
# Normalizzato: output1383.wav
# Normalizzato: output1384.wav
# Normalizzato: output1385.wav
# Normalizzato: output1386.wav
# Normalizzato: output1387.wav
# Normalizzato: output1388.wav
# Normalizzato: output1389.wav
# Normalizzato: output139.wav
# Normalizzato: output1390.wav
# Normalizzato: output1391.wav
# Normalizzato: output1392.wav
# Normalizzato: output1393.wav
# Normalizzato: output1394.wav
# Normalizzato: output1395.wav
# Normalizzato: output1396.wav
# Normalizzato: output1397.wav
# Normalizzato: output1399.wav
# Normalizzato: output1398.wav
# Normalizzato: output14.wav
# Normalizzato: output140.wav
# Normalizzato: output1400.wav
# Normalizzato: output1401.wav
# Normalizzato: output1402.wav
# Normalizzato: output1403.wav
# Normalizzato: output1404.wav
# Normalizzato: output1067.wav
# Normalizzato: output1068.wav
# Normalizzato: output1069.wav
# Normalizzato: output107.wav
# Normalizzato: output1070.wav
# Normalizzato: output1071.wav
# Normalizzato: output1072.wav
# Normalizzato: output1073.wav
# Normalizzato: output1074.wav
# Normalizzato: output1075.wav
# Normalizzato: output1076.wav
# Normalizzato: output1077.wav
# Normalizzato: output1078.wav
# Normalizzato: output1079.wav
# Normalizzato: output108.wav
# Normalizzato: output1080.wav
# Normalizzato: output1081.wav
# Normalizzato: output1082.wav
# Normalizzato: output1083.wav
# Normalizzato: output1084.wav
# Normalizzato: output1085.wav
# Normalizzato: output1086.wav
# Normalizzato: output1087.wav
# Normalizzato: output1088.wav
# Normalizzato: output1089.wav
# Normalizzato: output703.wav
# Normalizzato: output704.wav
# Normalizzato: output705.wav
# Normalizzato: output706.wav
# Normalizzato: output707.wav
# Normalizzato: output708.wav
# Normalizzato: output709.wav
# Normalizzato: output71.wav
# Normalizzato: output710.wav
# Normalizzato: output711.wav
# Normalizzato: output712.wav
# Normalizzato: output713.wav
# Normalizzato: output714.wav
# Normalizzato: output715.wav
# Normalizzato: output716.wav
# Normalizzato: output717.wav
# Normalizzato: output718.wav
# Normalizzato: output719.wav
# Normalizzato: output2352.wav
# Normalizzato: output2353.wav
# Normalizzato: output2354.wav
# Normalizzato: output2355.wav
# Normalizzato: output2356.wav
# Normalizzato: output2357.wav
# Normalizzato: output2358.wav
# Normalizzato: output2359.wav
# Normalizzato: output236.wav
# Normalizzato: output2360.wav
# Normalizzato: output2361.wav
# Normalizzato: output2362.wav
# Normalizzato: output2363.wav
# Normalizzato: output2364.wav
# Normalizzato: output2365.wav
# Normalizzato: output2366.wav
# Normalizzato: output2367.wav
# Normalizzato: output2368.wav
# Normalizzato: output2369.wav
# Normalizzato: output237.wav
# Normalizzato: output2370.wav
# Normalizzato: output2371.wav
# Normalizzato: output2372.wav
# Normalizzato: output2373.wav
# Normalizzato: output320.wav
# Normalizzato: output321.wav
# Normalizzato: output322.wav
# Normalizzato: output323.wav
# Normalizzato: output324.wav
# Normalizzato: output325.wav
# Normalizzato: output326.wav
# Normalizzato: output327.wav
# Normalizzato: output329.wav
# Normalizzato: output328.wav
# Normalizzato: output33.wav
# Normalizzato: output330.wav
# Normalizzato: output331.wav
# Normalizzato: output332.wav
# Normalizzato: output333.wav
# Normalizzato: output334.wav
# Normalizzato: output335.wav
# Normalizzato: output336.wav
# Normalizzato: output337.wav
# Normalizzato: output338.wav
# Normalizzato: output339.wav
# Normalizzato: output34.wav
# Normalizzato: output340.wav
# Normalizzato: output341.wav
# Normalizzato: output2583.wav
# Normalizzato: output2584.wav
# Normalizzato: output2585.wav
# Normalizzato: output2586.wav
# Normalizzato: output2587.wav
# Normalizzato: output2588.wav
# Normalizzato: output2589.wav
# Normalizzato: output259.wav
# Normalizzato: output2590.wav
# Normalizzato: output2591.wav
# Normalizzato: output2592.wav
# Normalizzato: output2593.wav
# Normalizzato: output2594.wav
# Normalizzato: output2595.wav
# Normalizzato: output2596.wav
# Normalizzato: output2597.wav
# Normalizzato: output2598.wav
# Normalizzato: output2599.wav
# Normalizzato: output26.wav
# Normalizzato: output260.wav
# Normalizzato: output2600.wav
# Normalizzato: output2601.wav
# Normalizzato: output2602.wav
# Normalizzato: output2603.wav
# Normalizzato: output2604.wav
# Normalizzato: output2605.wav
# Normalizzato: output2606.wav
# Normalizzato: output2607.wav
# Normalizzato: output2608.wav
# Normalizzato: output2609.wav
# Normalizzato: output261.wav
# Normalizzato: output2610.wav
# Normalizzato: output2611.wav
# Normalizzato: output2612.wav
# Normalizzato: output2613.wav
# Normalizzato: output2036.wav
# Normalizzato: output2037.wav
# Normalizzato: output2038.wav
# Normalizzato: output2039.wav
# Normalizzato: output204.wav
# Normalizzato: output2040.wav
# Normalizzato: output2041.wav
# Normalizzato: output2042.wav
# Normalizzato: output2043.wav
# Normalizzato: output2044.wav
# Normalizzato: output2045.wav
# Normalizzato: output2046.wav
# Normalizzato: output2047.wav
# Normalizzato: output2048.wav
# Normalizzato: output2049.wav
# Normalizzato: output205.wav
# Normalizzato: output2050.wav
# Normalizzato: output2051.wav
# Normalizzato: output2052.wav
# Normalizzato: output2053.wav
# Normalizzato: output2054.wav
# Normalizzato: output2055.wav
# Normalizzato: output2056.wav
# Normalizzato: output2057.wav
# Normalizzato: output2058.wav
# Normalizzato: output2059.wav
# Normalizzato: output206.wav
# Normalizzato: output2060.wav
# Normalizzato: output2061.wav
# Normalizzato: output2062.wav
# Normalizzato: output2063.wav
# Normalizzato: output2064.wav
# Normalizzato: output2065.wav
# Normalizzato: output820.wav
# Normalizzato: output821.wav
# Normalizzato: output822.wav
# Normalizzato: output823.wav
# Normalizzato: output824.wav
# Normalizzato: output825.wav
# Normalizzato: output826.wav
# Normalizzato: output827.wav
# Normalizzato: output828.wav
# Normalizzato: output829.wav
# Normalizzato: output83.wav
# Normalizzato: output830.wav
# Normalizzato: output831.wav
# Normalizzato: output832.wav
# Normalizzato: output833.wav
# Normalizzato: output834.wav
# Normalizzato: output835.wav
# Normalizzato: output836.wav
# Normalizzato: output2258.wav
# Normalizzato: output2259.wav
# Normalizzato: output226.wav
# Normalizzato: output2260.wav
# Normalizzato: output2261.wav
# Normalizzato: output2262.wav
# Normalizzato: output2263.wav
# Normalizzato: output2264.wav
# Normalizzato: output2265.wav
# Normalizzato: output2266.wav
# Normalizzato: output2267.wav
# Normalizzato: output2268.wav
# Normalizzato: output2269.wav
# Normalizzato: output227.wav
# Normalizzato: output2270.wav
# Normalizzato: output2271.wav
# Normalizzato: output2272.wav
# Normalizzato: output2273.wav
# Normalizzato: output1719.wav
# Normalizzato: output1744.wav
# Normalizzato: output1771.wav
# Normalizzato: output1797.wav
# Normalizzato: output1818.wav
# Normalizzato: output1837.wav
# Normalizzato: output1860.wav
# Normalizzato: output1885.wav
# Normalizzato: output1907.wav
# Normalizzato: output1924.wav
# Normalizzato: output1944.wav
# Normalizzato: output1963.wav
# Normalizzato: output1983.wav
# Normalizzato: output2001.wav
# Normalizzato: output2018.wav
# Normalizzato: output2035.wav
# Normalizzato: output2066.wav
# Normalizzato: output2095.wav
# Normalizzato: output2117.wav
# Normalizzato: output2136.wav
# Normalizzato: output2163.wav
# Normalizzato: output2189.wav
# Normalizzato: output2216.wav
# Normalizzato: output2236.wav
# Normalizzato: output2257.wav
# Normalizzato: output2274.wav
# Normalizzato: output2303.wav
# Normalizzato: output233.wav
# Normalizzato: output2351.wav
# Normalizzato: output2374.wav
# Normalizzato: output2392.wav
# Normalizzato: output2408.wav
# Normalizzato: output2947.wav
# Normalizzato: output2948.wav
# Normalizzato: output2949.wav
# Normalizzato: output295.wav
# Normalizzato: output2950.wav
# Normalizzato: output2951.wav
# Normalizzato: output2952.wav
# Normalizzato: output2953.wav
# Normalizzato: output2954.wav
# Normalizzato: output2955.wav
# Normalizzato: output2956.wav
# Normalizzato: output2957.wav
# Normalizzato: output2958.wav
# Normalizzato: output2959.wav
# Normalizzato: output296.wav
# Normalizzato: output2960.wav
# Normalizzato: output2961.wav
# Normalizzato: output2962.wav
# Normalizzato: output2963.wav
# Normalizzato: output1585.wav
# Normalizzato: output1586.wav
# Normalizzato: output1587.wav
# Normalizzato: output1588.wav
# Normalizzato: output1589.wav
# Normalizzato: output159.wav
# Normalizzato: output1590.wav
# Normalizzato: output1591.wav
# Normalizzato: output1592.wav
# Normalizzato: output1593.wav
# Normalizzato: output1594.wav
# Normalizzato: output1595.wav
# Normalizzato: output1596.wav
# Normalizzato: output1597.wav
# Normalizzato: output1598.wav
# Normalizzato: output1599.wav
# Normalizzato: output16.wav
# Normalizzato: output160.wav
# Normalizzato: output1600.wav
# Normalizzato: output1601.wav
# Normalizzato: output1602.wav
# Normalizzato: output1603.wav
# Normalizzato: output1604.wav
# Normalizzato: output1605.wav
# Normalizzato: output1606.wav
# Normalizzato: output1607.wav
# Normalizzato: output1608.wav
# Normalizzato: output1609.wav
# Normalizzato: output2137.wav
# Normalizzato: output2138.wav
# Normalizzato: output2139.wav
# Normalizzato: output214.wav
# Normalizzato: output2140.wav
# Normalizzato: output2141.wav
# Normalizzato: output2142.wav
# Normalizzato: output2143.wav
# Normalizzato: output2144.wav
# Normalizzato: output2145.wav
# Normalizzato: output2146.wav
# Normalizzato: output2147.wav
# Normalizzato: output2148.wav
# Normalizzato: output2149.wav
# Normalizzato: output215.wav
# Normalizzato: output2150.wav
# Normalizzato: output2151.wav
# Normalizzato: output2152.wav
# Normalizzato: output2153.wav
# Normalizzato: output2154.wav
# Normalizzato: output2155.wav
# Normalizzato: output2156.wav
# Normalizzato: output2157.wav
# Normalizzato: output2158.wav
# Normalizzato: output2159.wav
# Normalizzato: output216.wav
# Normalizzato: output2160.wav
# Normalizzato: output2161.wav
# Normalizzato: output2162.wav
# Normalizzato: output1234.wav
# Normalizzato: output1235.wav
# Normalizzato: output1236.wav
# Normalizzato: output1237.wav
# Normalizzato: output1238.wav
# Normalizzato: output1239.wav
# Normalizzato: output124.wav
# Normalizzato: output1240.wav
# Normalizzato: output1241.wav
# Normalizzato: output1242.wav
# Normalizzato: output1243.wav
# Normalizzato: output1244.wav
# Normalizzato: output1245.wav
# Normalizzato: output1246.wav
# Normalizzato: output1247.wav
# Normalizzato: output1248.wav
# Normalizzato: output1249.wav
# Normalizzato: output125.wav
# Normalizzato: output1250.wav
# Normalizzato: output1251.wav
# Normalizzato: output928.wav
# Normalizzato: output929.wav
# Normalizzato: output93.wav
# Normalizzato: output930.wav
# Normalizzato: output931.wav
# Normalizzato: output932.wav
# Normalizzato: output933.wav
# Normalizzato: output934.wav
# Normalizzato: output935.wav
# Normalizzato: output936.wav
# Normalizzato: output937.wav
# Normalizzato: output938.wav
# Normalizzato: output939.wav
# Normalizzato: output94.wav
# Normalizzato: output940.wav
# Normalizzato: output941.wav
# Normalizzato: output942.wav
# Normalizzato: output943.wav
# Normalizzato: output944.wav
# Normalizzato: output945.wav
# Normalizzato: output1772.wav
# Normalizzato: output1773.wav
# Normalizzato: output1774.wav
# Normalizzato: output1775.wav
# Normalizzato: output1776.wav
# Normalizzato: output1777.wav
# Normalizzato: output1778.wav
# Normalizzato: output1779.wav
# Normalizzato: output178.wav
# Normalizzato: output1780.wav
# Normalizzato: output1781.wav
# Normalizzato: output1782.wav
# Normalizzato: output1783.wav
# Normalizzato: output1784.wav
# Normalizzato: output1785.wav
# Normalizzato: output1786.wav
# Normalizzato: output1787.wav
# Normalizzato: output1788.wav
# Normalizzato: output1789.wav
# Normalizzato: output179.wav
# Normalizzato: output1790.wav
# Normalizzato: output1791.wav
# Normalizzato: output1792.wav
# Normalizzato: output1793.wav
# Normalizzato: output1794.wav
# Normalizzato: output1795.wav
# Normalizzato: output1796.wav
# Normalizzato: output1861.wav
# Normalizzato: output1862.wav
# Normalizzato: output1863.wav
# Normalizzato: output1864.wav
# Normalizzato: output1865.wav
# Normalizzato: output1866.wav
# Normalizzato: output1867.wav
# Normalizzato: output1868.wav
# Normalizzato: output1869.wav
# Normalizzato: output187.wav
# Normalizzato: output1870.wav
# Normalizzato: output1871.wav
# Normalizzato: output1872.wav
# Normalizzato: output1873.wav
# Normalizzato: output1874.wav
# Normalizzato: output1875.wav
# Normalizzato: output1876.wav
# Normalizzato: output1877.wav
# Normalizzato: output1878.wav
# Normalizzato: output1879.wav
# Normalizzato: output188.wav
# Normalizzato: output1880.wav
# Normalizzato: output1881.wav
# Normalizzato: output1882.wav
# Normalizzato: output1883.wav
# Normalizzato: output1884.wav
# Normalizzato: output1018.wav
# Normalizzato: output1019.wav
# Normalizzato: output102.wav
# Normalizzato: output1020.wav
# Normalizzato: output1021.wav
# Normalizzato: output1022.wav
# Normalizzato: output1023.wav
# Normalizzato: output1024.wav
# Normalizzato: output1025.wav
# Normalizzato: output1026.wav
# Normalizzato: output1027.wav
# Normalizzato: output1028.wav
# Normalizzato: output1029.wav
# Normalizzato: output103.wav
# Normalizzato: output1030.wav
# Normalizzato: output1031.wav
# Normalizzato: output1032.wav
# Normalizzato: output1033.wav
# Normalizzato: output1034.wav
# Normalizzato: output1035.wav
# Normalizzato: output1036.wav
# Normalizzato: output1037.wav
# Normalizzato: output1038.wav
# Normalizzato: output1039.wav
# Normalizzato: output104.wav
# Normalizzato: output168.wav
# Normalizzato: output1680.wav
# Normalizzato: output1681.wav
# Normalizzato: output1682.wav
# Normalizzato: output1683.wav
# Normalizzato: output1684.wav
# Normalizzato: output1685.wav
# Normalizzato: output1686.wav
# Normalizzato: output1687.wav
# Normalizzato: output1688.wav
# Normalizzato: output1689.wav
# Normalizzato: output169.wav
# Normalizzato: output1690.wav
# Normalizzato: output1691.wav
# Normalizzato: output1692.wav
# Normalizzato: output1693.wav
# Normalizzato: output1694.wav
# Normalizzato: output2785.wav
# Normalizzato: output2786.wav
# Normalizzato: output2787.wav
# Normalizzato: output2788.wav
# Normalizzato: output2789.wav
# Normalizzato: output279.wav
# Normalizzato: output2790.wav
# Normalizzato: output2791.wav
# Normalizzato: output2792.wav
# Normalizzato: output2793.wav
# Normalizzato: output2794.wav
# Normalizzato: output2795.wav
# Normalizzato: output2796.wav
# Normalizzato: output2797.wav
# Normalizzato: output2798.wav
# Normalizzato: output2799.wav
# Normalizzato: output28.wav
# Normalizzato: output280.wav
# Normalizzato: output2800.wav
# Normalizzato: output2801.wav
# Normalizzato: output2802.wav
# Normalizzato: output2803.wav
# Normalizzato: output2804.wav
# Normalizzato: output2805.wav
# Normalizzato: output2806.wav
# Normalizzato: output2807.wav
# Normalizzato: output2808.wav
# Normalizzato: output2809.wav
# Normalizzato: output281.wav
# Normalizzato: output2810.wav
# Normalizzato: output2811.wav
# Normalizzato: output2812.wav
# Normalizzato: output2687.wav
# Normalizzato: output2688.wav
# Normalizzato: output2689.wav
# Normalizzato: output269.wav
# Normalizzato: output2690.wav
# Normalizzato: output2691.wav
# Normalizzato: output2692.wav
# Normalizzato: output2693.wav
# Normalizzato: output2694.wav
# Normalizzato: output2695.wav
# Normalizzato: output2696.wav
# Normalizzato: output2697.wav
# Normalizzato: output2698.wav
# Normalizzato: output2699.wav
# Normalizzato: output27.wav
# Normalizzato: output270.wav
# Normalizzato: output2700.wav
# Normalizzato: output2701.wav
# Normalizzato: output2702.wav
# Normalizzato: output2703.wav
# Normalizzato: output2704.wav
# Normalizzato: output2705.wav
# Normalizzato: output2706.wav
# Normalizzato: output2707.wav
# Normalizzato: output2708.wav
# Normalizzato: output2709.wav
# Normalizzato: output271.wav
# Normalizzato: output2710.wav
# Normalizzato: output2711.wav
# Normalizzato: output454.wav
# Normalizzato: output455.wav
# Normalizzato: output456.wav
# Normalizzato: output457.wav
# Normalizzato: output458.wav
# Normalizzato: output459.wav
# Normalizzato: output46.wav
# Normalizzato: output460.wav
# Normalizzato: output461.wav
# Normalizzato: output462.wav
# Normalizzato: output463.wav
# Normalizzato: output464.wav
# Normalizzato: output465.wav
# Normalizzato: output466.wav
# Normalizzato: output467.wav
# Normalizzato: output468.wav
# Normalizzato: output469.wav
# Normalizzato: output47.wav
# Normalizzato: output470.wav
# Normalizzato: output471.wav
# Normalizzato: output472.wav
# Normalizzato: output473.wav
# Normalizzato: output1339.wav
# Normalizzato: output134.wav
# Normalizzato: output1340.wav
# Normalizzato: output1341.wav
# Normalizzato: output1342.wav
# Normalizzato: output1343.wav
# Normalizzato: output1344.wav
# Normalizzato: output1345.wav
# Normalizzato: output1346.wav
# Normalizzato: output1347.wav
# Normalizzato: output1348.wav
# Normalizzato: output1349.wav
# Normalizzato: output135.wav
# Normalizzato: output1350.wav
# Normalizzato: output1351.wav
# Normalizzato: output1352.wav
# Normalizzato: output1353.wav
# Normalizzato: output1354.wav
# Normalizzato: output1355.wav
# Normalizzato: output2458.wav
# Normalizzato: output2459.wav
# Normalizzato: output246.wav
# Normalizzato: output2460.wav
# Normalizzato: output2461.wav
# Normalizzato: output2462.wav
# Normalizzato: output2463.wav
# Normalizzato: output2464.wav
# Normalizzato: output2465.wav
# Normalizzato: output2466.wav
# Normalizzato: output2467.wav
# Normalizzato: output2468.wav
# Normalizzato: output2469.wav
# Normalizzato: output247.wav
# Normalizzato: output2470.wav
# Normalizzato: output2471.wav
# Normalizzato: output2472.wav
# Normalizzato: output2473.wav
# Normalizzato: output2474.wav
# Normalizzato: output2475.wav
# Normalizzato: output2476.wav
# Normalizzato: output2477.wav
# Normalizzato: output2478.wav
# Normalizzato: output2479.wav
# Normalizzato: output248.wav
# Normalizzato: output2480.wav
# Normalizzato: output2481.wav
# Normalizzato: output2482.wav
# Normalizzato: output2483.wav
# Normalizzato: output2484.wav
# Normalizzato: output2880.wav
# Normalizzato: output2881.wav
# Normalizzato: output2882.wav
# Normalizzato: output2883.wav
# Normalizzato: output2884.wav
# Normalizzato: output2885.wav
# Normalizzato: output2886.wav
# Normalizzato: output2887.wav
# Normalizzato: output2888.wav
# Normalizzato: output2889.wav
# Normalizzato: output289.wav
# Normalizzato: output2890.wav
# Normalizzato: output2891.wav
# Normalizzato: output2892.wav
# Normalizzato: output2893.wav
# Normalizzato: output2894.wav
# Normalizzato: output2895.wav
# Normalizzato: output2896.wav
# Normalizzato: output1495.wav
# Normalizzato: output1496.wav
# Normalizzato: output1497.wav
# Normalizzato: output1498.wav
# Normalizzato: output1499.wav
# Normalizzato: output15.wav
# Normalizzato: output150.wav
# Normalizzato: output1500.wav
# Normalizzato: output1501.wav
# Normalizzato: output1502.wav
# Normalizzato: output1503.wav
# Normalizzato: output1504.wav
# Normalizzato: output1505.wav
# Normalizzato: output1506.wav
# Normalizzato: output1507.wav
# Normalizzato: output1508.wav
# Normalizzato: output1509.wav
# Normalizzato: output151.wav
# Normalizzato: output1510.wav
# Normalizzato: output1511.wav
# Normalizzato: output1512.wav
# Normalizzato: output1423.wav
# Normalizzato: output1424.wav
# Normalizzato: output1425.wav
# Normalizzato: output1426.wav
# Normalizzato: output1427.wav
# Normalizzato: output1428.wav
# Normalizzato: output1429.wav
# Normalizzato: output143.wav
# Normalizzato: output1430.wav
# Normalizzato: output1431.wav
# Normalizzato: output1432.wav
# Normalizzato: output1433.wav
# Normalizzato: output1434.wav
# Normalizzato: output1435.wav
# Normalizzato: output1436.wav
# Normalizzato: output1437.wav
# Normalizzato: output1438.wav
# Normalizzato: output1439.wav
# Normalizzato: output364.wav
# Normalizzato: output365.wav
# Normalizzato: output366.wav
# Normalizzato: output367.wav
# Normalizzato: output368.wav
# Normalizzato: output369.wav
# Normalizzato: output37.wav
# Normalizzato: output370.wav
# Normalizzato: output371.wav
# Normalizzato: output372.wav
# Normalizzato: output373.wav
# Normalizzato: output374.wav
# Normalizzato: output375.wav
# Normalizzato: output376.wav
# Normalizzato: output377.wav
# Normalizzato: output378.wav
# Normalizzato: output379.wav
# Normalizzato: output38.wav
# Normalizzato: output380.wav
# Normalizzato: output381.wav
# Normalizzato: output382.wav
# Normalizzato: output383.wav
# Normalizzato: output384.wav
# Normalizzato: output385.wav
# Normalizzato: output386.wav
# Normalizzato: output387.wav
# Normalizzato: output388.wav
# Normalizzato: output389.wav
# Normalizzato: output39.wav
# Normalizzato: output589.wav
# Normalizzato: output59.wav
# Normalizzato: output590.wav
# Normalizzato: output591.wav
# Normalizzato: output592.wav
# Normalizzato: output593.wav
# Normalizzato: output594.wav
# Normalizzato: output595.wav
# Normalizzato: output596.wav
# Normalizzato: output597.wav
# Normalizzato: output598.wav
# Normalizzato: output599.wav
# Normalizzato: output6.wav
# Normalizzato: output60.wav
# Normalizzato: output600.wav
# Normalizzato: output601.wav
# Normalizzato: output602.wav
# Normalizzato: output603.wav
# Normalizzato: output604.wav
# Normalizzato: output605.wav
# Normalizzato: output606.wav
# Normalizzato: output607.wav
# Normalizzato: output608.wav
# Normalizzato: output609.wav
# Normalizzato: output653.wav
# Normalizzato: output654.wav
# Normalizzato: output655.wav
# Normalizzato: output656.wav
# Normalizzato: output657.wav
# Normalizzato: output658.wav
# Normalizzato: output659.wav
# Normalizzato: output66.wav
# Normalizzato: output660.wav
# Normalizzato: output661.wav
# Normalizzato: output662.wav
# Normalizzato: output663.wav
# Normalizzato: output664.wav
# Normalizzato: output665.wav
# Normalizzato: output666.wav
# Normalizzato: output667.wav
# Normalizzato: output668.wav
# Normalizzato: output669.wav
# Normalizzato: output67.wav
# Normalizzato: output670.wav
# Normalizzato: output671.wav
# Normalizzato: output672.wav
# Normalizzato: output673.wav
# Normalizzato: output674.wav
# Normalizzato: output675.wav
# Normalizzato: output676.wav
# Normalizzato: output677.wav
# Normalizzato: output678.wav
# Normalizzato: output679.wav
# Normalizzato: output68.wav
# Normalizzato: output680.wav
# Normalizzato: output681.wav
# Normalizzato: output682.wav
# Normalizzato: output111.wav
# Normalizzato: output1110.wav
# Normalizzato: output1111.wav
# Normalizzato: output1112.wav
# Normalizzato: output1113.wav
# Normalizzato: output1114.wav
# Normalizzato: output1115.wav
# Normalizzato: output1116.wav
# Normalizzato: output1117.wav
# Normalizzato: output1118.wav
# Normalizzato: output1119.wav
# Normalizzato: output112.wav
# Normalizzato: output1120.wav
# Normalizzato: output1121.wav
# Normalizzato: output1122.wav
# Normalizzato: output1123.wav
# Normalizzato: output1124.wav
# Normalizzato: output1125.wav
# Normalizzato: output1126.wav
# Normalizzato: output1127.wav
# Normalizzato: output1128.wav
# Normalizzato: output1945.wav
# Normalizzato: output1946.wav
# Normalizzato: output1947.wav
# Normalizzato: output1948.wav
# Normalizzato: output1949.wav
# Normalizzato: output195.wav
# Normalizzato: output1950.wav
# Normalizzato: output1951.wav
# Normalizzato: output1952.wav
# Normalizzato: output1953.wav
# Normalizzato: output1954.wav
# Normalizzato: output1955.wav
# Normalizzato: output1956.wav
# Normalizzato: output1957.wav
# Normalizzato: output1958.wav
# Normalizzato: output1959.wav
# Normalizzato: output196.wav
# Normalizzato: output1960.wav
# Normalizzato: output1961.wav
# Normalizzato: output1962.wav
# Normalizzato: output3036.wav
# Normalizzato: output3037.wav
# Normalizzato: output3038.wav
# Normalizzato: output3039.wav
# Normalizzato: output304.wav
# Normalizzato: output3040.wav
# Normalizzato: output3041.wav
# Normalizzato: output3042.wav
# Normalizzato: output3043.wav
# Normalizzato: output3044.wav
# Normalizzato: output3045.wav
# Normalizzato: output3046.wav
# Normalizzato: output3047.wav
# Normalizzato: output3048.wav
# Normalizzato: output3049.wav
# Normalizzato: output305.wav
# Normalizzato: output3050.wav
# Normalizzato: output3051.wav
# Normalizzato: output3052.wav
# Normalizzato: output856.wav
# Normalizzato: output857.wav
# Normalizzato: output858.wav
# Normalizzato: output859.wav
# Normalizzato: output86.wav
# Normalizzato: output860.wav
# Normalizzato: output861.wav
# Normalizzato: output862.wav
# Normalizzato: output863.wav
# Normalizzato: output864.wav
# Normalizzato: output865.wav
# Normalizzato: output866.wav
# Normalizzato: output867.wav
# Normalizzato: output868.wav
# Normalizzato: output869.wav
# Normalizzato: output87.wav
# Normalizzato: output870.wav
# Normalizzato: output2561.wav
# Normalizzato: output2562.wav
# Normalizzato: output2563.wav
# Normalizzato: output2564.wav
# Normalizzato: output2565.wav
# Normalizzato: output2566.wav
# Normalizzato: output2567.wav
# Normalizzato: output2568.wav
# Normalizzato: output2569.wav
# Normalizzato: output257.wav
# Normalizzato: output2570.wav
# Normalizzato: output2571.wav
# Normalizzato: output2572.wav
# Normalizzato: output2573.wav
# Normalizzato: output2574.wav
# Normalizzato: output2575.wav
# Normalizzato: output2576.wav
# Normalizzato: output2577.wav
# Normalizzato: output2578.wav
# Normalizzato: output2579.wav
# Normalizzato: output258.wav
# Normalizzato: output2580.wav
# Normalizzato: output2581.wav
# Normalizzato: output119.wav
# Normalizzato: output1190.wav
# Normalizzato: output1191.wav
# Normalizzato: output1192.wav
# Normalizzato: output1193.wav
# Normalizzato: output1194.wav
# Normalizzato: output1195.wav
# Normalizzato: output1196.wav
# Normalizzato: output1197.wav
# Normalizzato: output1198.wav
# Normalizzato: output1199.wav
# Normalizzato: output12.wav
# Normalizzato: output120.wav
# Normalizzato: output1200.wav
# Normalizzato: output1201.wav
# Normalizzato: output1202.wav
# Normalizzato: output1203.wav
# Normalizzato: output1204.wav
# Normalizzato: output1205.wav
# Normalizzato: output1206.wav
# Normalizzato: output1207.wav
# Normalizzato: output1208.wav
# Normalizzato: output1209.wav
# Normalizzato: output121.wav
# Normalizzato: output1210.wav
# Normalizzato: output720.wav
# Normalizzato: output721.wav
# Normalizzato: output722.wav
# Normalizzato: output723.wav
# Normalizzato: output724.wav
# Normalizzato: output725.wav
# Normalizzato: output726.wav
# Normalizzato: output727.wav
# Normalizzato: output728.wav
# Normalizzato: output729.wav
# Normalizzato: output73.wav
# Normalizzato: output730.wav
# Normalizzato: output731.wav
# Normalizzato: output732.wav
# Normalizzato: output733.wav
# Normalizzato: output734.wav
# Normalizzato: output735.wav
# Normalizzato: output736.wav
# Normalizzato: output737.wav
# Normalizzato: output738.wav
# Normalizzato: output739.wav
# Normalizzato: output74.wav
# Normalizzato: output740.wav
# Normalizzato: output2019.wav
# Normalizzato: output202.wav
# Normalizzato: output2020.wav
# Normalizzato: output2021.wav
# Normalizzato: output2022.wav
# Normalizzato: output2023.wav
# Normalizzato: output2024.wav
# Normalizzato: output2025.wav
# Normalizzato: output2026.wav
# Normalizzato: output2027.wav
# Normalizzato: output2028.wav
# Normalizzato: output2029.wav
# Normalizzato: output203.wav
# Normalizzato: output2030.wav
# Normalizzato: output2031.wav
# Normalizzato: output2032.wav
# Normalizzato: output2033.wav
# Normalizzato: output2034.wav
# Normalizzato: output1253.wav
# Normalizzato: output1254.wav
# Normalizzato: output1255.wav
# Normalizzato: output1256.wav
# Normalizzato: output1257.wav
# Normalizzato: output1258.wav
# Normalizzato: output1259.wav
# Normalizzato: output126.wav
# Normalizzato: output1260.wav
# Normalizzato: output1261.wav
# Normalizzato: output1262.wav
# Normalizzato: output1263.wav
# Normalizzato: output1264.wav
# Normalizzato: output1265.wav
# Normalizzato: output1266.wav
# Normalizzato: output1267.wav
# Normalizzato: output1268.wav
# Normalizzato: output1269.wav
# Normalizzato: output127.wav
# Normalizzato: output1270.wav
# Normalizzato: output1271.wav
# Normalizzato: output1272.wav
# Normalizzato: output1273.wav
# Normalizzato: output1274.wav
# Normalizzato: output1275.wav
# Normalizzato: output1276.wav
# Normalizzato: output1277.wav
# Normalizzato: output1278.wav
# Normalizzato: output1279.wav
# Normalizzato: output128.wav
# Normalizzato: output2217.wav
# Normalizzato: output2218.wav
# Normalizzato: output2219.wav
# Normalizzato: output222.wav
# Normalizzato: output2220.wav
# Normalizzato: output2221.wav
# Normalizzato: output2222.wav
# Normalizzato: output2223.wav
# Normalizzato: output2224.wav
# Normalizzato: output2225.wav
# Normalizzato: output2226.wav
# Normalizzato: output2227.wav
# Normalizzato: output2228.wav
# Normalizzato: output2229.wav
# Normalizzato: output223.wav
# Normalizzato: output2230.wav
# Normalizzato: output2231.wav
# Normalizzato: output2232.wav
# Normalizzato: output2233.wav
# Normalizzato: output2234.wav
# Normalizzato: output2235.wav
# Normalizzato: output947.wav
# Normalizzato: output948.wav
# Normalizzato: output949.wav
# Normalizzato: output95.wav
# Normalizzato: output950.wav
# Normalizzato: output951.wav
# Normalizzato: output952.wav
# Normalizzato: output953.wav
# Normalizzato: output954.wav
# Normalizzato: output955.wav
# Normalizzato: output956.wav
# Normalizzato: output957.wav
# Normalizzato: output958.wav
# Normalizzato: output959.wav
# Normalizzato: output96.wav
# Normalizzato: output960.wav
# Normalizzato: output961.wav
# Normalizzato: output962.wav
# Normalizzato: output963.wav
# Normalizzato: output964.wav
# Normalizzato: output965.wav
# Normalizzato: output966.wav
# Normalizzato: output967.wav
# Normalizzato: output968.wav
# Normalizzato: output969.wav
# Normalizzato: output97.wav
# Normalizzato: output970.wav
# Normalizzato: output2965.wav
# Normalizzato: output2966.wav
# Normalizzato: output2967.wav
# Normalizzato: output2968.wav
# Normalizzato: output2969.wav
# Normalizzato: output297.wav
# Normalizzato: output2970.wav
# Normalizzato: output2971.wav
# Normalizzato: output2972.wav
# Normalizzato: output2973.wav
# Normalizzato: output2974.wav
# Normalizzato: output2975.wav
# Normalizzato: output2976.wav
# Normalizzato: output2977.wav
# Normalizzato: output2978.wav
# Normalizzato: output2979.wav
# Normalizzato: output298.wav
# ...
# Normalizzato: output2829.wav
# Normalizzato: output283.wav
# Normalizzato: output2830.wav
# Normalizzato: output2831.wav
# Normalizzato: output2832.wav
# Normalizzato: output2833.wav
# Normalizzato: output2834.wav
# Normalizzato: output2835.wav
# Normalizzato: output2836.wav
# Normalizzato: output2837.wav
# Normalizzato: output254.wav
# Normalizzato: output2540.wav
# Normalizzato: output2541.wav
# Normalizzato: output2542.wav
# Normalizzato: output2543.wav
# Normalizzato: output2544.wav
# Normalizzato: output2545.wav
# Normalizzato: output2546.wav
# Normalizzato: output2547.wav
# Normalizzato: output2548.wav
# Normalizzato: output2549.wav
# Normalizzato: output255.wav
# Normalizzato: output2550.wav
# Normalizzato: output2551.wav
# Normalizzato: output2552.wav
# Normalizzato: output2553.wav
# Normalizzato: output2554.wav
# Normalizzato: output2555.wav
# Normalizzato: output2556.wav
# Normalizzato: output2557.wav
# Normalizzato: output2558.wav
# Normalizzato: output2559.wav
# Normalizzato: output256.wav
# Normalizzato: output1090.wav
# Normalizzato: output1091.wav
# Normalizzato: output1092.wav
# Normalizzato: output1093.wav
# Normalizzato: output1094.wav
# Normalizzato: output1095.wav
# Normalizzato: output1096.wav
# Normalizzato: output1097.wav
# Normalizzato: output1098.wav
# Normalizzato: output1099.wav
# Normalizzato: output11.wav
# Normalizzato: output110.wav
# Normalizzato: output1100.wav
# Normalizzato: output1101.wav
# Normalizzato: output1102.wav
# Normalizzato: output1103.wav
# Normalizzato: output1104.wav
# Normalizzato: output1105.wav
# Normalizzato: output1106.wav
# Normalizzato: output1107.wav
# Normalizzato: output1108.wav
# Normalizzato: output2330.wav
# Normalizzato: output2331.wav
# Normalizzato: output2332.wav
# Normalizzato: output2333.wav
# Normalizzato: output2334.wav
# Normalizzato: output2335.wav
# Normalizzato: output2336.wav
# Normalizzato: output2337.wav
# Normalizzato: output2338.wav
# Normalizzato: output2339.wav
# Normalizzato: output234.wav
# Normalizzato: output2340.wav
# Normalizzato: output2341.wav
# Normalizzato: output2342.wav
# Normalizzato: output2343.wav
# Normalizzato: output2344.wav
# Normalizzato: output2345.wav
# Normalizzato: output2346.wav
# Normalizzato: output2347.wav
# Normalizzato: output2348.wav
# Normalizzato: output2349.wav
# Normalizzato: output235.wav
# Normalizzato: output2350.wav
# Normalizzato: output2713.wav
# Normalizzato: output2714.wav
# Normalizzato: output2715.wav
# Normalizzato: output2716.wav
# Normalizzato: output2718.wav
# Normalizzato: output2717.wav
# Normalizzato: output2719.wav
# Normalizzato: output272.wav
# Normalizzato: output2720.wav
# Normalizzato: output2721.wav
# Normalizzato: output2722.wav
# Normalizzato: output2723.wav
# Normalizzato: output2724.wav
# Normalizzato: output2725.wav
# Normalizzato: output2726.wav
# Normalizzato: output2727.wav
# Normalizzato: output2728.wav
# Normalizzato: output2729.wav
# Normalizzato: output273.wav
# Normalizzato: output2730.wav
# Normalizzato: output1798.wav
# Normalizzato: output1799.wav
# Normalizzato: output18.wav
# Normalizzato: output180.wav
# Normalizzato: output1800.wav
# Normalizzato: output1801.wav
# Normalizzato: output1802.wav
# Normalizzato: output1803.wav
# Normalizzato: output1804.wav
# Normalizzato: output1805.wav
# Normalizzato: output1806.wav
# Normalizzato: output1807.wav
# Normalizzato: output1808.wav
# Normalizzato: output1809.wav
# Normalizzato: output181.wav
# Normalizzato: output1810.wav
# Normalizzato: output1811.wav
# Normalizzato: output1812.wav
# Normalizzato: output1813.wav
# Normalizzato: output1814.wav
# Normalizzato: output1815.wav
# Normalizzato: output1816.wav
# Normalizzato: output1817.wav
# Normalizzato: output2857.wav
# Normalizzato: output2858.wav
# Normalizzato: output2859.wav
# Normalizzato: output286.wav
# Normalizzato: output2860.wav
# Normalizzato: output2861.wav
# Normalizzato: output2862.wav
# Normalizzato: output2863.wav
# Normalizzato: output2864.wav
# Normalizzato: output2865.wav
# Normalizzato: output2866.wav
# Normalizzato: output2867.wav
# Normalizzato: output2868.wav
# Normalizzato: output2869.wav
# Normalizzato: output287.wav
# Normalizzato: output2870.wav
# Normalizzato: output2871.wav
# Normalizzato: output2872.wav
# Normalizzato: output2873.wav
# Normalizzato: output2874.wav
# Normalizzato: output2875.wav
# Normalizzato: output2876.wav
# Normalizzato: output2877.wav
# Normalizzato: output2878.wav
# Normalizzato: output2879.wav
# Normalizzato: output1212.wav
# Normalizzato: output1213.wav
# Normalizzato: output1214.wav
# Normalizzato: output1215.wav
# Normalizzato: output1216.wav
# Normalizzato: output1217.wav
# Normalizzato: output1218.wav
# Normalizzato: output1219.wav
# Normalizzato: output122.wav
# Normalizzato: output1220.wav
# Normalizzato: output1221.wav
# Normalizzato: output1222.wav
# Normalizzato: output1223.wav
# Normalizzato: output1224.wav
# Normalizzato: output1225.wav
# Normalizzato: output1226.wav
# Normalizzato: output1227.wav
# Normalizzato: output1228.wav
# Normalizzato: output1229.wav
# Normalizzato: output123.wav
# Normalizzato: output1230.wav
# Normalizzato: output1231.wav
# Normalizzato: output1232.wav
# Normalizzato: output2926.wav
# Normalizzato: output2927.wav
# Normalizzato: output2928.wav
# Normalizzato: output2929.wav
# Normalizzato: output293.wav
# Normalizzato: output2930.wav
# Normalizzato: output2931.wav
# Normalizzato: output2932.wav
# Normalizzato: output2933.wav
# Normalizzato: output2934.wav
# Normalizzato: output2935.wav
# Normalizzato: output2936.wav
# Normalizzato: output2937.wav
# Normalizzato: output2938.wav
# Normalizzato: output2939.wav
# Normalizzato: output294.wav
# Normalizzato: output2940.wav
# Normalizzato: output2941.wav
# Normalizzato: output2942.wav
# Normalizzato: output2943.wav
# Normalizzato: output2944.wav
# Normalizzato: output2945.wav
# Normalizzato: output1925.wav
# Normalizzato: output1926.wav
# Normalizzato: output1927.wav
# Normalizzato: output1928.wav
# Normalizzato: output1929.wav
# Normalizzato: output193.wav
# Normalizzato: output1930.wav
# Normalizzato: output1931.wav
# Normalizzato: output1932.wav
# Normalizzato: output1933.wav
# Normalizzato: output1934.wav
# Normalizzato: output1935.wav
# Normalizzato: output1936.wav
# Normalizzato: output1937.wav
# Normalizzato: output1938.wav
# Normalizzato: output1939.wav
# Normalizzato: output194.wav
# Normalizzato: output1940.wav
# Normalizzato: output1941.wav
# Normalizzato: output1942.wav
# Normalizzato: output1943.wav
# Normalizzato: output1964.wav
# Normalizzato: output1965.wav
# Normalizzato: output1966.wav
# Normalizzato: output1967.wav
# Normalizzato: output1968.wav
# Normalizzato: output1969.wav
# Normalizzato: output197.wav
# Normalizzato: output1970.wav
# Normalizzato: output1971.wav
# Normalizzato: output1972.wav
# Normalizzato: output1973.wav
# Normalizzato: output1974.wav
# Normalizzato: output1975.wav
# Normalizzato: output1976.wav
# Normalizzato: output1977.wav
# Normalizzato: output1978.wav
# Normalizzato: output1979.wav
# Normalizzato: output198.wav
# Normalizzato: output1980.wav
# Normalizzato: output1981.wav
# Normalizzato: output1982.wav
# Normalizzato: output684.wav
# Normalizzato: output685.wav
# Normalizzato: output686.wav
# Normalizzato: output687.wav
# Normalizzato: output688.wav
# Normalizzato: output689.wav
# Normalizzato: output69.wav
# Normalizzato: output690.wav
# Normalizzato: output691.wav
# Normalizzato: output692.wav
# Normalizzato: output693.wav
# Normalizzato: output694.wav
# Normalizzato: output695.wav
# Normalizzato: output696.wav
# Normalizzato: output697.wav
# Normalizzato: output698.wav
# Normalizzato: output699.wav
# Normalizzato: output7.wav
# Normalizzato: output70.wav
# Normalizzato: output700.wav
# Normalizzato: output701.wav
# Normalizzato: output1475.wav
# Normalizzato: output1476.wav
# Normalizzato: output1477.wav
# Normalizzato: output1478.wav
# Normalizzato: output1479.wav
# Normalizzato: output148.wav
# Normalizzato: output1480.wav
# Normalizzato: output1481.wav
# Normalizzato: output1482.wav
# Normalizzato: output1483.wav
# Normalizzato: output1484.wav
# Normalizzato: output1485.wav
# Normalizzato: output1486.wav
# Normalizzato: output1487.wav
# Normalizzato: output1488.wav
# Normalizzato: output1489.wav
# Normalizzato: output149.wav
# Normalizzato: output1490.wav
# Normalizzato: output1491.wav
# Normalizzato: output1492.wav
# Normalizzato: output1493.wav
# Normalizzato: output2237.wav
# Normalizzato: output2238.wav
# Normalizzato: output2239.wav
# Normalizzato: output224.wav
# Normalizzato: output2240.wav
# Normalizzato: output2241.wav
# Normalizzato: output2242.wav
# Normalizzato: output2243.wav
# Normalizzato: output2244.wav
# Normalizzato: output2245.wav
# Normalizzato: output2246.wav
# Normalizzato: output2247.wav
# Normalizzato: output2248.wav
# Normalizzato: output2249.wav
# Normalizzato: output225.wav
# Normalizzato: output2250.wav
# Normalizzato: output2251.wav
# Normalizzato: output2252.wav
# Normalizzato: output2253.wav
# Normalizzato: output2254.wav
# Normalizzato: output2255.wav
# Normalizzato: output2256.wav
# Normalizzato: output475.wav
# Normalizzato: output476.wav
# Normalizzato: output477.wav
# Normalizzato: output478.wav
# Normalizzato: output479.wav
# Normalizzato: output48.wav
# Normalizzato: output480.wav
# Normalizzato: output481.wav
# Normalizzato: output482.wav
# Normalizzato: output483.wav
# Normalizzato: output484.wav
# Normalizzato: output485.wav
# Normalizzato: output486.wav
# Normalizzato: output487.wav
# Normalizzato: output488.wav
# Normalizzato: output489.wav
# Normalizzato: output49.wav
# Normalizzato: output490.wav
# Normalizzato: output1886.wav
# Normalizzato: output1887.wav
# Normalizzato: output1888.wav
# Normalizzato: output1889.wav
# Normalizzato: output189.wav
# Normalizzato: output1890.wav
# Normalizzato: output1891.wav
# Normalizzato: output1892.wav
# Normalizzato: output1893.wav
# Normalizzato: output1894.wav
# Normalizzato: output1895.wav
# Normalizzato: output1896.wav
# Normalizzato: output1897.wav
# Normalizzato: output1898.wav
# Normalizzato: output1899.wav
# Normalizzato: output19.wav
# Normalizzato: output190.wav
# Normalizzato: output1900.wav
# Normalizzato: output1901.wav
# Normalizzato: output1902.wav
# Normalizzato: output1903.wav
# Normalizzato: output1904.wav
# Normalizzato: output1905.wav
# Normalizzato: output1906.wav
# Normalizzato: output1440.wav
# Normalizzato: output1441.wav
# Normalizzato: output1442.wav
# Normalizzato: output1443.wav
# Normalizzato: output1444.wav
# Normalizzato: output1445.wav
# Normalizzato: output1446.wav
# Normalizzato: output1447.wav
# Normalizzato: output1448.wav
# Normalizzato: output1449.wav
# Normalizzato: output145.wav
# Normalizzato: output1450.wav
# Normalizzato: output1451.wav
# Normalizzato: output1452.wav
# Normalizzato: output1453.wav
# Normalizzato: output1454.wav
# Normalizzato: output1455.wav
# Normalizzato: output1456.wav
# Normalizzato: output1322.wav
# Normalizzato: output1323.wav
# Normalizzato: output1324.wav
# Normalizzato: output1325.wav
# Normalizzato: output1326.wav
# Normalizzato: output1327.wav
# Normalizzato: output1328.wav
# Normalizzato: output1329.wav
# Normalizzato: output133.wav
# Normalizzato: output1330.wav
# Normalizzato: output1331.wav
# Normalizzato: output1332.wav
# Normalizzato: output1333.wav
# Normalizzato: output1334.wav
# Normalizzato: output1335.wav
# Normalizzato: output1336.wav
# Normalizzato: output1337.wav
# Normalizzato: output1406.wav
# Normalizzato: output1407.wav
# Normalizzato: output1408.wav
# Normalizzato: output1409.wav
# Normalizzato: output141.wav
# Normalizzato: output1410.wav
# Normalizzato: output1411.wav
# Normalizzato: output1412.wav
# Normalizzato: output1413.wav
# Normalizzato: output1414.wav
# Normalizzato: output1415.wav
# Normalizzato: output1416.wav
# Normalizzato: output1417.wav
# Normalizzato: output1418.wav
# Normalizzato: output1419.wav
# Normalizzato: output142.wav
# Normalizzato: output1420.wav
# Normalizzato: output1421.wav
# Normalizzato: output1660.wav
# Normalizzato: output1661.wav
# Normalizzato: output1662.wav
# Normalizzato: output1663.wav
# Normalizzato: output1664.wav
# Normalizzato: output1665.wav
# Normalizzato: output1666.wav
# Normalizzato: output1667.wav
# Normalizzato: output1668.wav
# Normalizzato: output1669.wav
# Normalizzato: output167.wav
# Normalizzato: output1670.wav
# Normalizzato: output1671.wav
# Normalizzato: output1672.wav
# Normalizzato: output1673.wav
# Normalizzato: output1674.wav
# Normalizzato: output1675.wav
# Normalizzato: output1676.wav
# Normalizzato: output1677.wav
# Normalizzato: output1678.wav
# Normalizzato: output2002.wav
# Normalizzato: output2003.wav
# Normalizzato: output2004.wav
# Normalizzato: output2005.wav
# Normalizzato: output2006.wav
# Normalizzato: output2007.wav
# Normalizzato: output2008.wav
# Normalizzato: output2009.wav
# Normalizzato: output201.wav
# Normalizzato: output2010.wav
# Normalizzato: output2011.wav
# Normalizzato: output2012.wav
# Normalizzato: output2013.wav
# Normalizzato: output2014.wav
# Normalizzato: output2015.wav
# Normalizzato: output2016.wav
# Normalizzato: output2017.wav
# Normalizzato: output2375.wav
# Normalizzato: output2376.wav
# Normalizzato: output2377.wav
# Normalizzato: output2378.wav
# Normalizzato: output2379.wav
# Normalizzato: output238.wav
# Normalizzato: output2381.wav
# Normalizzato: output2380.wav
# Normalizzato: output2382.wav
# Normalizzato: output2383.wav
# Normalizzato: output2384.wav
# Normalizzato: output2385.wav
# Normalizzato: output2386.wav
# Normalizzato: output2387.wav
# Normalizzato: output2388.wav
# Normalizzato: output2389.wav
# Normalizzato: output239.wav
# Normalizzato: output2390.wav
# Normalizzato: output2391.wav
# Normalizzato: output2751.wav
# Normalizzato: output2752.wav
# Normalizzato: output2753.wav
# Normalizzato: output2754.wav
# Normalizzato: output2755.wav
# Normalizzato: output2756.wav
# Normalizzato: output2757.wav
# Normalizzato: output2758.wav
# Normalizzato: output2759.wav
# Normalizzato: output276.wav
# Normalizzato: output2760.wav
# Normalizzato: output2761.wav
# Normalizzato: output2762.wav
# Normalizzato: output2763.wav
# Normalizzato: output2764.wav
# Normalizzato: output2765.wav
# Normalizzato: output2766.wav
# Normalizzato: output3016.wav
# Normalizzato: output3017.wav
# Normalizzato: output3018.wav
# Normalizzato: output3019.wav
# Normalizzato: output302.wav
# Normalizzato: output3020.wav
# Normalizzato: output3021.wav
# Normalizzato: output3022.wav
# Normalizzato: output3023.wav
# Normalizzato: output3024.wav
# Normalizzato: output3025.wav
# Normalizzato: output3026.wav
# Normalizzato: output3027.wav
# Normalizzato: output3028.wav
# Normalizzato: output3029.wav
# Normalizzato: output303.wav
# Normalizzato: output3030.wav
# Normalizzato: output3031.wav
# Normalizzato: output3032.wav
# Normalizzato: output3033.wav
# Normalizzato: output3034.wav
# Normalizzato: output770.wav
# Normalizzato: output771.wav
# Normalizzato: output772.wav
# Normalizzato: output773.wav
# Normalizzato: output774.wav
# Normalizzato: output775.wav
# Normalizzato: output776.wav
# Normalizzato: output777.wav
# Normalizzato: output778.wav
# Normalizzato: output779.wav
# Normalizzato: output78.wav
# Normalizzato: output780.wav
# Normalizzato: output781.wav
# Normalizzato: output782.wav
# Normalizzato: output783.wav
# Normalizzato: output784.wav
# Normalizzato: output785.wav
# Normalizzato: output786.wav
# Normalizzato: output804.wav
# Normalizzato: output805.wav
# Normalizzato: output806.wav
# Normalizzato: output807.wav
# Normalizzato: output808.wav
# Normalizzato: output809.wav
# Normalizzato: output81.wav
# Normalizzato: output810.wav
# Normalizzato: output811.wav
# Normalizzato: output812.wav
# Normalizzato: output813.wav
# Normalizzato: output814.wav
# Normalizzato: output815.wav
# Normalizzato: output816.wav
# Normalizzato: output817.wav
# Normalizzato: output818.wav
# Normalizzato: output819.wav
# Normalizzato: output838.wav
# Normalizzato: output839.wav
# Normalizzato: output84.wav
# Normalizzato: output840.wav
# Normalizzato: output841.wav
# Normalizzato: output842.wav
# Normalizzato: output843.wav
# Normalizzato: output844.wav
# Normalizzato: output845.wav
# Normalizzato: output846.wav
# Normalizzato: output847.wav
# Normalizzato: output848.wav
# Normalizzato: output849.wav
# Normalizzato: output85.wav
# Normalizzato: output850.wav
# Normalizzato: output851.wav
# Normalizzato: output852.wav
# Normalizzato: output853.wav
# Normalizzato: output854.wav
# Normalizzato: output872.wav
# Normalizzato: output873.wav
# Normalizzato: output874.wav
# Normalizzato: output875.wav
# Normalizzato: output876.wav
# Normalizzato: output877.wav
# Normalizzato: output878.wav
# Normalizzato: output879.wav
# Normalizzato: output88.wav
# Normalizzato: output880.wav
# Normalizzato: output881.wav
# Normalizzato: output882.wav
# Normalizzato: output883.wav
# Normalizzato: output884.wav
# Normalizzato: output885.wav
# Normalizzato: output886.wav
# Normalizzato: output887.wav
# Normalizzato: output888.wav

# %%
import os
import librosa
import soundfile as sf
import numpy as np

def normalize_audio(audio, target_level=-1.0):
    rms = np.sqrt(np.mean(audio**2))
    scalar = 10**(target_level / 20) / (rms + 1e-10)
    return audio * scalar

def process_audio_files(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for file_name in os.listdir(input_folder):
        if file_name.endswith(".wav"):
            input_path = os.path.join(input_folder, file_name)
            output_path = os.path.join(output_folder, file_name)
            
            audio, sr = librosa.load(input_path, sr=None)
            normalized_audio = normalize_audio(audio)
            
            sf.write(output_path, normalized_audio, sr)

input_folder = "/home/ms_ablasioli/alessandra/denoiser_backup_bcn/vibravox/noise_bone_train_bcn1"
output_folder = "/home/ms_ablasioli/alessandra/denoiser_backup_bcn/norm1/noise_bone_train_bcn1_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_air_test_bcn"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/noise_air_test_bcn_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_bone_test_bcn"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/noise_bone_test_bcn_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/clean_air_test"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/clean_air_test_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_air_validation_bcn"
output_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_air_validation_bcn_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/clean_air_validation"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/clean_air_validation_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_bone_validation_bcn"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/noise_bone_validation_bcn_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/clean_air_train_final"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/clean_air_train_final_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done

# %%
input_folder = "/home/alessandrab/denoiser_backup_bcn/vibravox/noise_air_train_bcn1"
output_folder = "/home/alessandrab/denoiser_backup_bcn/norm1/noise_air_train_bcn1_norm1"
process_audio_files(input_folder, output_folder)
print('done')
# Out:
# done
